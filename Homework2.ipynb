# %%
#Digit Product

def digit_Product(n):
    result=1
    while n>0:
        digit=n%10
        if digit!=0:
            result*=digit      
        n//=10
    return result
n=int(input())
digit_product(n)
# Out:
# 1023
# 6

# %%
# Largest Power of 3

def largest_power_3(n):
    result=1
    while result<=n:
        result*=3
    return int(result/3)
    
n=int(input())
largest_power_3(n)
# Out:
# 500
# 243

# %%
# Triangle
def Triangle(a,b,c):
    min_side=min(a,b,c)
    max_side=max(a,b,c)
    mid_side=a+b+c-min_side-max_side
    if max_side>=min_side+mid_side:
        return 0
    elif max_side**2==min_side**2+mid_side**2:
        return 1
    elif max_side**2<min_side**2+mid_side**2:
        return 2
    else:
        return 3

a=int(input())
b=int(input())
c=int(input())
if Triangle(a,b,c)==1:
    print('Right Triangle')
elif Triangle(a,b,c)==2:
        print('Acute Triangle')
elif Triangle(a,b,c)==0:
    print('No Triangle') 
else:
    print('Obtuse Triangle')
# Out:
# 4
# 4
# 4
# Acute Triangle

# %%
# The Root of the Number
def root(n):
    while n>10:
        result=0
        while n>0:
            result+=n%10
            n//=10
        n=result
        print(result)

    
n=int(input())
root(n)
# Out:
# 78996
# 39
# 12
# 3

# %%
#Number Of Divisors
def n_divisors(num):
    n=0
    for i in range(1, int(num/2)+1):
        if num%i==0:
            n+=1
    return n+1
n=int(input())
print(n_divisors(n))
# Out:
# 24
# 8

# %%
# Quadratic Equation
from math import sqrt
def quadratic(a,b,c):
    if a==0 and b==0 and c==0:
        print ('Non quadratic equation', 'Infinite Solutions',sep='\n')
    elif a==0 and b==0:
        print ('Non quadratic equation', 'No Solutions', sep='\n')
    elif a==0 and b!=0:
        print ('Non-quadratic equation', 'One Solution: '+ str(-c/b), sep='\n')
    else:
        d=b*b-4*a*c
        if(d<0):
            print ('Quadratic equation', 'Discriminant:'+ str(d), 'No Solutions', sep='\n')

        else:
            x1=(-b+sqrt(d))/(2*a)
            x2=(-b-sqrt(d))/(2*a)
            print ('Quadratic equation', 'Discriminant:'+ str(d), 'Two Solutions: '+ str(x1)+', ' + str(x2), sep='\n')

        
quadratic(1,2,1)
# Out:
# Quadratic equation
# Discriminant:0
# Two Solutions: -1.0, -1.0
